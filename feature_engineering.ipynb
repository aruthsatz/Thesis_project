# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("nba_games.csv")
data
# Out:
#         ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0     0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1     0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2     0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3     0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4     0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
# ...     ...    ...    ...    ...   ...   ...   ...   ...   ...   ...  ...
# 6264  0.592  0.557  0.342  0.253  15.8  78.0  51.1  72.5   4.4   7.0  ...
# 6265  0.638  0.593  0.373  0.293  28.1  78.4  55.1  59.0   8.1   4.7  ...
# 6266  0.468  0.429  0.380  0.207  18.2  63.9  36.3  58.8   7.7   4.8  ...
# 6267  0.547  0.500  0.321  0.256  21.6  85.3  52.1  65.7   2.3   5.9  ...
# 6268  0.499  0.482  0.333  0.274  25.0  80.7  56.4  55.3   6.2  11.5  ...
#
#       ast_opp  stl_opp  blk_opp  tov_opp  pf_opp  pts_opp  home  away  \
# ...

# %%
data.shape
# Out:
# (6269, 66)

# %%
data.describe()
# Out:
#                ts%         efg%         3par          ftr         orb%  \
# count  6269.000000  6269.000000  6269.000000  6269.000000  6269.000000
# mean      0.574545     0.539204     0.387154     0.263929    23.153438
# std       0.061806     0.066105     0.078179     0.091440     7.256690
# min       0.380000     0.301000     0.109000     0.041000     0.000000
# 25%       0.531000     0.494000     0.333000     0.200000    18.000000
# 50%       0.572000     0.537000     0.383000     0.256000    22.900000
# 75%       0.617000     0.584000     0.438000     0.321000    28.100000
# max       0.798000     0.787000     0.692000     0.739000    50.000000
#
#               drb%         trb%         ast%         stl%         blk%  ...  \
# count  6269.000000  6269.000000  6269.000000  6269.000000  6269.000000  ...
# mean     77.590796    50.566613    60.550949     7.525969     9.022332  ...
# std       7.129995     5.292790     9.410224     2.846617     4.451263  ...
# ...

# %%
data["date"] = pd.to_datetime(data["date"], dayfirst=True)

# %%
data.date.dt.month
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 6264     6
# 6265     6
# 6266     6
# 6267     6
# 6268     6
# Name: date, Length: 6269, dtype: int64

# %% [markdown]
# Test is a copy of the orginal that I use for testing

# %%
test = data.copy()

# %%
test.head()
# Out:
#      ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0  0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1  0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2  0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3  0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4  0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
#
#    ast_opp  stl_opp  blk_opp  tov_opp  pf_opp  pts_opp  home  away       date  \
# 0       18        8        5       16      20       87   BOS   PHI 2018-10-16
# 1       21       12        6       14      21      100   GSW   OKC 2018-10-16
# 2       26        5        4       21      25      113   CHO   MIL 2018-10-17
# 3       28        9        5       17      23      100   DET   BRK 2018-10-17
# 4       36        8        3       12      25      131   HOU   NOP 2018-10-17
#
#    winner
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# ...

# %% [markdown]
# Seperating the seasons to create a dataset to use for machine learning. Containing only numbers

# %%
begin_date = pd.to_datetime('2019-10-22')

# %%
season1 = test[(test['date'] < begin_date)]
len(season1)
# Out:
# 1312

# %%
begin_date = pd.to_datetime('2019-10-22') 
end_date = pd.to_datetime('2020-10-11')

# %%
season2 = test[(test['date'] >= begin_date) & (test['date'] <= end_date)]
len(season2)
# Out:
# 1143

# %%
begin_date2 = pd.to_datetime('2020-12-22') 
end_date2 = pd.to_datetime('2021-07-20')

# %%
season3 = test[(test['date'] >= begin_date2) & (test['date'] <= end_date2)]
len(season3)
# Out:
# 1171

# %%
begin_date3 = pd.to_datetime('2021-10-19')
end_date3 = pd.to_datetime('2022-06-16')

# %%
season4 = test[(test['date'] >= begin_date3) & (test['date'] <= end_date3)]
len(season4)
# Out:
# 1323

# %%
begin_date4 = pd.to_datetime('2022-10-18')
end_date4 = pd.to_datetime('2023-06-12')

# %%
season5 = test[(test['date'] >= begin_date4) & (test['date'] <= end_date4)]
len(season5)
# Out:
# 1320

# %%
# adding rank column to the seasons

# %%
team_map_18_19 = {'MIL': 1, 'TOR': 2, 'GSW': 3, 'DEN': 4, 'HOU': 5, 'POR': 6, 'PHI': 7, 'UTA': 8, 'BOS': 9, 'OKC': 10, 'IND': 11, 'LAC': 12, 'SAS': 13, 'BRK': 14, 'ORL': 15, 'DET': 16, 'CHO': 17, 'MIA': 18, 'SAC': 19, 'LAL': 20, 'MIN': 21, 'DAL': 22, 'MEM': 23, 'NOP': 24, 'WAS': 25, 'ATL': 26, 'CHI': 27, 'CLE': 28, 'PHO': 29, 'NYK': 30}
team_map_19_20 = {'MIL': 1, 'TOR': 2, 'LAL': 3, 'LAC': 4, 'BOS': 5, 'DEN': 6, 'IND': 7, 'HOU': 8, 'MIA': 9, 'OKC': 10, 'UTA': 11, 'DAL': 12, 'PHI': 13, 'BRK': 14, 'POR': 15, 'MEM': 16, 'PHO': 17, 'ORL': 18, 'SAS': 19, 'SAC': 20, 'NOP': 21, 'WAS': 22, 'CHO': 23, 'CHI': 24, 'NYK': 25, 'ATL': 26, 'DET': 27, 'CLE': 28, 'MIN': 29, 'GSW': 30}
team_map_20_21 = {'UTA': 1, 'PHO': 2, 'PHI': 3, 'BRK': 4, 'DEN': 5, 'LAC': 6, 'MIL': 7, 'DAL': 8, 'LAL': 9, 'POR': 10, 'ATL': 11, 'NYK': 12, 'MIA': 13, 'GSW': 14, 'MEM': 15, 'BOS': 16, 'WAS': 17, 'IND': 18, 'CHO': 19, 'SAS': 20, 'CHI': 21, 'NOP': 22, 'SAC': 23, 'TOR': 24, 'MIN': 25, 'CLE': 26, 'OKC': 27, 'ORL': 28, 'DET': 29, 'HOU': 30}
team_map_21_22 = {'PHO': 1, 'MEM': 2, 'GSW': 3, 'MIA': 4, 'DAL': 5, 'BOS': 6, 'MIL': 7, 'PHI': 8, 'UTA': 9, 'DEN': 10, 'TOR': 11, 'CHI': 12, 'MIN': 13, 'BRK': 14, 'CLE': 15, 'ATL': 16, 'CHO': 17, 'LAC': 18, 'NYK': 19, 'NOP': 20, 'WAS': 21, 'SAS': 22, 'LAL': 23, 'SAC': 24, 'POR': 25, 'IND': 26, 'OKC': 27, 'DET': 28, 'ORL': 29, 'HOU': 30}
team_map_22_23 = {'MIL': 1, 'BOS': 2, 'PHI': 3, 'DEN': 4, 'CLE': 5, 'MEM': 6, 'SAC': 7, 'NYK': 8, 'BRK': 9, 'PHO': 10, 'GSW': 11, 'LAC': 12, 'MIA': 13, 'LAL': 14, 'MIN': 15, 'NOP': 16, 'ATL': 17, 'TOR': 18, 'CHI': 19, 'OKC': 20, 'DAL': 21, 'UTA': 22, 'IND': 23, 'WAS': 24, 'ORL': 25, 'POR': 26, 'CHO': 27, 'HOU': 28, 'SAS': 29, 'DET': 30}

# %%
season1['rank_home'] = ''
season1['rank_away'] = ''
# Out:
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\1032106652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season1['rank_home'] = ''
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\1032106652.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season1['rank_away'] = ''

# %%
season1
# Out:
#         ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0     0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1     0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2     0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3     0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4     0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
# ...     ...    ...    ...    ...   ...   ...   ...   ...   ...   ...  ...
# 1307  0.493  0.431  0.404  0.277  29.4  85.0  53.8  48.6   8.0   4.2  ...
# 1308  0.523  0.462  0.396  0.330  27.1  84.8  50.6  69.4   8.0   6.8  ...
# 1309  0.527  0.500  0.346  0.269  20.0  82.9  51.9  74.3   6.3  11.1  ...
# 1310  0.542  0.494  0.376  0.318  29.5  83.3  53.8  50.0   6.4  12.5  ...
# 1311  0.590  0.556  0.388  0.375  28.2  73.8  51.9  71.8   9.5  12.2  ...
#
#       blk_opp  tov_opp  pf_opp  pts_opp  home  away       date  winner  \
# ...

# %%
season2['rank_home'] = season2['home'].map(team_map_18_19)

season2['rank_away'] = season2['away'].map(team_map_18_19)
season2[['rank_home', 'rank_away']]
# Out:
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\1451161198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season2['rank_home'] = season2['home'].map(team_map_18_19)
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\1451161198.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season2['rank_away'] = season2['away'].map(team_map_18_19)
#       rank_home  rank_away
# 1312         12         20
# 1313          2         24
# 1314         14         21
# 1315         17         27
# ...

# %%
season3['rank_home'] = season3['home'].map(team_map_19_20)
season3['rank_away'] = season3['away'].map(team_map_19_20)
season3[['rank_home', 'rank_away']]
# Out:
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\2369752580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season3['rank_home'] = season3['home'].map(team_map_19_20)
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\2369752580.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season3['rank_away'] = season3['away'].map(team_map_19_20)
#       rank_home  rank_away
# 2455         14         30
# 2456          3          4
# 2457          5          1
# 2458         24         26
# ...

# %%
season4['rank_home'] = season4['home'].map(team_map_20_21)
season4['rank_away'] = season4['away'].map(team_map_20_21)
season4[['rank_home', 'rank_away']]
# Out:
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\3414276187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season4['rank_home'] = season4['home'].map(team_map_20_21)
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\3414276187.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season4['rank_away'] = season4['away'].map(team_map_20_21)
#       rank_home  rank_away
# 3626          9         14
# 3627          7          4
# 3628         19         18
# 3629         29         21
# ...

# %%
season5['rank_home'] = season5['home'].map(team_map_21_22)
season5['rank_away'] = season5['away'].map(team_map_21_22)
season5[['rank_home', 'rank_away']]
# Out:
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\3425003348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season5['rank_home'] = season5['home'].map(team_map_21_22)
# C:\Users\aruth\AppData\Local\Temp\ipykernel_17504\3425003348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season5['rank_away'] = season5['away'].map(team_map_21_22)
#       rank_home  rank_away
# 4949          6          8
# 4950          3         23
# 4951         16         30
# 4952         14         20
# ...

# %%
seasons = pd.concat([season1, season2, season3, season4, season5])
seasons.head(20)
# Out:
#       ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0   0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1   0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2   0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3   0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4   0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
# 5   0.626  0.627  0.313  0.157  38.2  86.3  67.1  61.7   2.1  12.7  ...
# 6   0.497  0.443  0.318  0.273  17.6  73.1  45.6  60.0   3.0  14.3  ...
# 7   0.559  0.515  0.333  0.313  20.8  83.7  50.5  46.7  10.6  11.1  ...
# 8   0.483  0.452  0.266  0.330  26.9  72.5  49.5  51.3   6.8  10.9  ...
# 9   0.687  0.660  0.420  0.198  17.6  79.2  53.7  79.5   5.4   3.6  ...
# 10  0.568  0.553  0.200  0.189  11.4  86.5  45.7  34.7   7.6   5.8  ...
# 11  0.530  0.489  0.269  0.312  37.3  70.2  53.1  55.0   3.1   5.6  ...
# ...

# %%
seasons.drop(['home', 'away'], axis=1, inplace=True)
seasons.head()
# Out:
#      ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0  0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1  0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2  0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3  0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4  0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
#
#    ast_opp  stl_opp  blk_opp  tov_opp  pf_opp  pts_opp       date  winner  \
# 0       18        8        5       16      20       87 2018-10-16       1
# 1       21       12        6       14      21      100 2018-10-16       1
# 2       26        5        4       21      25      113 2018-10-17       0
# 3       28        9        5       17      23      100 2018-10-17       1
# 4       36        8        3       12      25      131 2018-10-17       0
#
#    rank_home  rank_away
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 66 columns]

# %% [markdown]
# ## DROPPING WINNER

# %%
seasons.drop('winner', axis=1, inplace=True)
seasons.head()
# Out:
#      ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0  0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1  0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2  0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3  0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4  0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
#
#    trb_opp  ast_opp  stl_opp  blk_opp  tov_opp  pf_opp  pts_opp       date  \
# 0       47       18        8        5       16      20       87 2018-10-16
# 1       45       21       12        6       14      21      100 2018-10-16
# 2       57       26        5        4       21      25      113 2018-10-17
# 3       39       28        9        5       17      23      100 2018-10-17
# 4       54       36        8        3       12      25      131 2018-10-17
#
#    rank_home  rank_away
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 65 columns]

# %% [markdown]
# ## DROPPING DATE

# %%
seasons.drop('date', axis=1, inplace=True)
seasons.head()
# Out:
#      ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0  0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1  0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2  0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3  0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4  0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
#
#    drb_opp  trb_opp  ast_opp  stl_opp  blk_opp  tov_opp  pf_opp  pts_opp  \
# 0       41       47       18        8        5       16      20       87
# 1       29       45       21       12        6       14      21      100
# 2       46       57       26        5        4       21      25      113
# 3       34       39       28        9        5       17      23      100
# 4       40       54       36        8        3       12      25      131
#
#    rank_home  rank_away
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 64 columns]

# %%
# somehow this random character got pickup when data scraping
seasons = seasons.replace(['`1'], 1)

# %%
seasons = seasons.replace([''], 0)

# %%
seasons.head()
# Out:
#      ts%   efg%   3par    ftr  orb%  drb%  trb%  ast%  stl%  blk%  ...  \
# 0  0.509  0.490  0.381  0.144  22.6  87.8  53.9  50.0   6.7   8.2  ...
# 1  0.525  0.479  0.274  0.189  37.0  71.9  56.3  66.7   6.8  13.0  ...
# 2  0.551  0.533  0.413  0.239  16.4  74.4  41.8  51.2   7.8  17.6  ...
# 3  0.506  0.457  0.261  0.239  29.2  86.5  54.1  53.8   5.0   9.1  ...
# 4  0.546  0.511  0.522  0.261  16.7  67.4  40.7  53.8   7.8   9.6  ...
#
#    drb_opp  trb_opp  ast_opp  stl_opp  blk_opp  tov_opp  pf_opp  pts_opp  \
# 0       41       47       18        8        5       16      20       87
# 1       29       45       21       12        6       14      21      100
# 2       46       57       26        5        4       21      25      113
# 3       34       39       28        9        5       17      23      100
# 4       40       54       36        8        3       12      25      131
#
#    rank_home  rank_away
# 0          0          0
# 1          0          0
# ...

# %% [markdown]
# ## CONVERTING SEASONS TO NUMPY ARRAY

# %%
print(len(seasons))
sum(seasons.rank_home.isna())
# Out:
# 6269
# 0

# %%
seasons_test = pd.concat([season2, season3, season4, season5])
print(len(seasons_test))
# Out:
# 4957

# %%
def old_dataset_filter(home_code, away_code, dataset):
    team1_home = dataset[dataset["home"] == home_code].tail(20)
    team1_away = dataset[dataset["away"] == home_code].tail(20)
    team1_df = pd.concat([team1_home, team1_away])
    #team1_df = team1_df.sort_values('date', ascending=False)
    
    team2_home = dataset[dataset["home"] == away_code].tail(20)
    team2_away = dataset[dataset["away"] == away_code].tail(20)
    team2_df = pd.concat([team2_home, team2_away])
    #team2_df = team2_df.sort_values('date', ascending=False)
    #daway = dataset[dataset["home"] == away_code].tail(20)

    combined_data = pd.concat([team1_df, team2_df])
    return combined_data

# %% [markdown]
# This 'dataset_filter' function grabs previous 40 games for both teams
# and combines them into a dataset.

# %%
def dataset_filter(home_code, away_code, game_date):
    dataset = test.loc[(test['date'] < game_date)]

    team1_home = dataset[dataset["home"] == home_code].tail(20)
    team1_away = dataset[dataset["away"] == home_code].tail(20)
    team1_df = pd.concat([team1_home, team1_away])

    team2_home = dataset[dataset["home"] == away_code].tail(20)
    team2_away = dataset[dataset["away"] == away_code].tail(20)
    team2_df = pd.concat([team2_home, team2_away])

    combined_data = pd.concat([team1_df, team2_df])
    # both the seasons and test datasets have the same index
    # below I am saving the index column to a list and applying it to the seasons dataset so that it returns the same data
    
    combined_data_index = list(combined_data.index)
    combined_seasons_data = seasons.iloc[combined_data_index]
    # 11/15 i changed seasons to seasons_std to return a standardized dataset
    
    return combined_seasons_data

# %% [markdown]
# - loops through each row in our test dataset
# - first grabs the date and checks that it is not in the first season (the first season is for training)
# - runs the dataset_filter function and saved new dataset to 'file'
# - change the date, then lastly save to pdf

# %%
def date_field_preprocessing(file_date):
    ## This method deletes days from the 'date' field
    file_date_list = list(file_date)

    new_date_list = []
    for t in file_date:
        date_num = str(t).replace(' days', '')
        new_date_list.append(date_num)
        
        
    new_date_series = pd.Series(new_date_list)
    return new_date_series

# %% [markdown]
# - change the filepaths to
# train -> home_wins
#          away_wins
# test  -> home_wins
#          away_wins
#
#  - make sure the only grab season 2 3 and 4 for training
#  - and season 5 for test

# %%
for index in test.index:
    game_date = test['date'][index]
    #last_szn1_game = '2019-06-13'
    
    if game_date < pd.Timestamp('2022-10-18'):
        # these if statements ensure we are not grabbing from the first season or last(test) season
        if game_date > pd.Timestamp('2019-06-13'):
            # the date above  is the last game of the first season
            homecode = test['home'][index]
            awaycode = test['away'][index]
            pts_home = test['pts'][index]
            pts_opp = test['pts_opp'][index]

            #changing date to date difference
            file = dataset_filter(homecode, awaycode, game_date)
            file = file.copy()
            
            #file_date = game_date - file['date']
            #new_file_date_series = date_field_preprocessing(file_date)
            #file.drop('date', axis=1, inplace=True)
            #file['date'] = new_file_date_series
            #file['date'] = file.date.replace(' days', '')
            
            output_date = str(game_date)[0:10]
            output_date = output_date.replace('-', '_')
            filename = f'{homecode}_{awaycode}_{output_date}.csv'
            filepath1 = f'X_train/home_wins/{filename}'
            filepath2 = f'X_train/away_wins/{filename}'
            filepath3 = f'X_test/home_wins/{filename}'
            filepath4 = f'X_test/away_wins/{filename}'

            
            

            # .copy() to create new df and reduce change for error
            new_file = file.copy()


            if pts_home > pts_opp:
                file.to_csv(filepath1)
            else: 
                file.to_csv(filepath2)
    else: 
            
        if game_date > pd.Timestamp('2019-06-13'):
            # the date above  is the last game of the first season
            homecode = test['home'][index]
            awaycode = test['away'][index]
            pts_home = test['pts'][index]
            pts_opp = test['pts_opp'][index]

            #changing date to date difference
            file = dataset_filter(homecode, awaycode, game_date)
            file = file.copy()
            #file_date = game_date - file['date']
            #new_file_date_series = date_field_preprocessing(file_date)
            #file.drop('date', axis=1, inplace=True)

            #file['date'] = str(file['date'])[0:3]
            
            output_date = str(game_date)[0:10]
            output_date = output_date.replace('-', '_')
            filename = f'{homecode}_{awaycode}_{output_date}.csv'
            filepath1 = f'X_train/home_wins/{filename}'
            filepath2 = f'X_train/away_wins/{filename}'
            filepath3 = f'X_test/home_wins/{filename}'
            filepath4 = f'X_test/away_wins/{filename}'

           
            

            # .copy() to create new df and reduce change for error
            new_file = file.copy()


            if pts_home > pts_opp:
                file.to_csv(filepath3)
            else: 
                file.to_csv(filepath4)
